# %% [markdown]
# # 01 — Exploratory data analysis
#
# Skeleton only: load `data/raw/public.jsonl` (after you add it), print schema stats and previews. No model loading.

# %%
# TODO: paths via configs/default.yaml + src/utils/paths.py once implemented
# TODO: load_jsonl, basic counts, head()
